# %%
import numpy as np

# %%
lst = [1, 2, 3, 4]
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
print('1D Aaray')
a = np.array([(1, 2, 3), (4, 5, 6)])
print (a)
# Out:
# 1D Aaray
# [[1 2 3]
#  [4 5 6]]

# %%
type (a)
# Out:
# numpy.ndarray

# %%
print(a.size)
# Out:
# 6

# %%
print(a.shape)
# Out:
# (2, 3)

# %%
print(a.dtype)
# Out:
# int64

# %%
a.transpose()
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])
